# %% [markdown]
# <a href="https://colab.research.google.com/github/nischay25/NLP/blob/main/EXP19.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk
from nltk.wsd import lesk
from nltk.corpus import wordnet
nltk.download('wordnet')
nltk.download('omw-1.4')
sentence = " I went to the bank to deposit money"
word = sentence.split()
result = lesk(word,"bank")
print("sentence:",sentence)
print("Ambiguous word: Bank")
if result:
  print("Selected sence: ",result.name())
  print("Definition:",result.definition())
else:
  print("No sense found")
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# sentence:  I went to the bank to deposit money
# Ambiguous word: Bank
# Selected sence:  savings_bank.n.02
# Definition: a container (usually with a slot in the top) for keeping money at home
